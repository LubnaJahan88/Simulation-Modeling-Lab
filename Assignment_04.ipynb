# %%
#LUBNA JAHAN LIPA
#ID: 0432310005101088

import random
import numpy as np
import math

# %%
R = 88
radius = R / 10
range_max = radius
name = "Lubna Jahan Lipa"
name_letters = 14
min_points = 200 * name_letters
print("Range Used: [0,", range_max, "]")
print("Radius:", radius)
print("Minimum Points:", min_points)
# Out:
# Range Used: [0, 8.8 ]
# Radius: 8.8
# Minimum Points: 2800

# %%
def is_inside_circle(x, y, r):
    return x**2 + y**2 <= r**2
